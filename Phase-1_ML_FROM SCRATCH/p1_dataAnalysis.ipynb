# %%
print("python for data analysis")
# Out:
# python for data analysis

# %%
import pandas as pd

df = pd.read_excel('D:/TECHTRECK/Raw_Retail_Sales_Dataset_5000.xlsx', engine='openpyxl')
pd.set_option('display.max_columns', 50)  #to display all columns in the output

# %%
print("First 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#     Order_ID  Order_Date Order_Time               Branch Sales_Channel  \
# 0  ORD000001  2025-04-25      21:05               Smouha   TikTok Shop
# 1  ORD000002  2025-01-07      14:10              Stanley      WhatsApp
# 2  ORD000003  2025-03-22      15:15               Smouha         Store
# 3  ORD000004  2025-10-01      12:15                Miami     Instagram
# 4  ORD000005  2025-08-05      20:50  Downtown Alexandria     Instagram
#
#   Customer_ID Customer_Gender  Customer_Age Customer_Area Product_ID  \
# 0       C0433            Male            19        Smouha       P001
# 1       C0105            Male            42        Smouha       P025
# 2       C0678            Male            36        Smouha       P018
# 3       C0389          Female            58      Victoria       P023
# 4       C0147          Female            26       Stanley       P030
#
#            Product_Name            Category      Brand  Unit_Price  Quantity  \
# ...

# %%
df.tail(10)
# Out:
#        Order_ID  Order_Date Order_Time   Branch Sales_Channel Customer_ID  \
# 4990  ORD004991  2026-04-21      11:30   Smouha       Website       C0881
# 4991  ORD004992  2025-07-03      14:05   Smouha         Store       C0251
# 4992  ORD004993  2025-05-07      19:50  Roushdy      WhatsApp       C0693
# 4993  ORD004994  2026-03-30      14:05  Stanley      WhatsApp       C0804
# 4994  ORD004995  2026-02-01      17:30   Smouha   TikTok Shop       C0183
# 4995  ORD004996  2026-03-23      17:30    Miami       Website       C0033
# 4996  ORD004997  2026-05-24      12:15    Miami         Store       C0406
# 4997  ORD004998  2025-09-21      13:15  Stanley     Instagram       C0334
# 4998  ORD004999  2026-02-02      10:50    Miami   TikTok Shop       C0778
# 4999  ORD005000  2026-03-06      22:15    Miami      WhatsApp       C0121
#
#      Customer_Gender  Customer_Age Customer_Area Product_ID      Product_Name  \
# ...

# %%
print("Random 5 rows:")
df.sample(5, random_state=42) # Displaying random rows
# Out:
# Random 5 rows:
#        Order_ID  Order_Date Order_Time               Branch Sales_Channel  \
# 1501  ORD001502  2025-08-16      22:30              Mandara       Website
# 2586  ORD002587  2025-10-25      12:45  Downtown Alexandria       Website
# 2653  ORD002654  2025-07-03      12:00              Stanley   TikTok Shop
# 1055  ORD001056  2025-11-02      16:45              Mandara     Instagram
# 705   ORD000706  2025-12-17      20:20              Roushdy      WhatsApp
#
#      Customer_ID Customer_Gender  Customer_Age Customer_Area Product_ID  \
# 1501       C0351          Female            29       Stanley       P009
# 2586       C0089          Female            37       Stanley       P018
# 2653       C0736          Female            42    Sidi Bishr       P005
# 1055       C0662          Female            28      Sporting       P025
# 705        C0609            Male            38         Gleem       P018
#
# ...

# %%
df.sample(5)
# Out:
#        Order_ID  Order_Date Order_Time      Branch Sales_Channel Customer_ID  \
# 2346  ORD002347  2025-03-04      11:15  Sidi Bishr         Store       C0119
# 218   ORD000219  2026-04-14      10:00     Stanley     Instagram       C0595
# 239   ORD000240  2026-01-04      14:00       Miami      WhatsApp       C0007
# 4140  ORD004141  2026-06-04      18:10      Smouha         Store       C0560
# 1847  ORD001848  2025-03-15      12:00     Stanley         Store       C0160
#
#      Customer_Gender  Customer_Age Customer_Area Product_ID  Product_Name  \
# 2346            Male            31        Smouha       P007  Basic Blouse
# 218             Male            38         Gleem       P004    Polo Shirt
# 239           Female            32       Stanley       P015        Slides
# 4140            Male            37      Victoria       P007  Basic Blouse
# 1847          Female            38      Sporting       P019           Cap
#
# ...

# %%
df.shape
row , col = df.shape
print(row , col)
# Out:
# 5000 28

# %%
df.columns
## to convert to normal list
list(df.columns)
# Out:
# ['Order_ID',
#  'Order_Date',
#  'Order_Time',
#  'Branch',
#  'Sales_Channel',
#  'Customer_ID',
#  'Customer_Gender',
#  'Customer_Age',
#  'Customer_Area',
#  'Product_ID',
#  'Product_Name',
#  'Category',
#  'Brand',
#  'Unit_Price',
#  'Quantity',
#  'Discount_Percent',
#  'Payment_Method',
#  'Marketing_Source',
#  'Campaign_Name',
#  'Returned',
#  'Return_Reason',
#  'Rating',
#  'Stock_Available_Before_Sale',
#  'Supplier',
#  'Lead_Time_Days',
#  'Competitor_Price',
#  'Weather',
#  'Season']

# %%
print(df.index) ##where start and end
print(df.index.min())  ## the first
print(df.index.max())  ## the last
# Out:
# RangeIndex(start=0, stop=5000, step=1)
# 0
# 4999

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Order_ID                     5000 non-null   object
#  1   Order_Date                   5000 non-null   object
#  2   Order_Time                   5000 non-null   object
#  3   Branch                       5000 non-null   object
#  4   Sales_Channel                5000 non-null   object
#  5   Customer_ID                  5000 non-null   object
#  6   Customer_Gender              5000 non-null   object
#  7   Customer_Age                 5000 non-null   int64
#  8   Customer_Area                5000 non-null   object
#  9   Product_ID                   5000 non-null   object
#  10  Product_Name                 5000 non-null   object
#  11  Category                     5000 non-null   object
#  12  Brand                        5000 non-null   object
# ...

# %%
print(df.dtypes)
print("----------------------------------------")
print(df.dtypes.value_counts())
# Out:
# Order_ID                        object
# Order_Date                      object
# Order_Time                      object
# Branch                          object
# Sales_Channel                   object
# Customer_ID                     object
# Customer_Gender                 object
# Customer_Age                     int64
# Customer_Area                   object
# Product_ID                      object
# Product_Name                    object
# Category                        object
# Brand                           object
# Unit_Price                     float64
# Quantity                         int64
# Discount_Percent               float64
# Payment_Method                  object
# Marketing_Source                object
# Campaign_Name                   object
# Returned                        object
# Return_Reason                   object
# Rating                         float64
# Stock_Available_Before_Sale      int64
# Supplier                        object
# ...

# %% [markdown]
# # Data frame :  عباره عن جدول r +c  من داتا هتدهالو
# # students = ({"id":[24030099 , 24030100 , 24030101]
# #             ,"names" : ["ziad salah" , "ziad radwan" , "ziad mohamed"]
# #             ,"gpa" : [3.59 , 3.3 , 3.48]})
#
# # st = pd.DataFrame(students)
# # print(st)
#
#
# # # series : عمود واحد
# #degree = [ 100 , 102 , 103]
# #names = ["ziad" , "ahmed" , "medo"]
# #dts = pd.Series(degree , index = names)
# #print(dts)
#
# #search :
# #print(dts[dts == 100])
#
#
# #read csv files :
# #df = pd.read_csv("C:/Users/Zoz/Desktop/myfile.csv")

# %%
students = ({"id":[24030099 , 24030100 , 24030101]
            ,"names" : ["ziad salah" , "ziad radwan" , "ziad mohamed"]
            ,"gpa" : [3.59 , 3.3 , 3.48]})

st = pd.DataFrame(students)
print(st)
# Out:
#          id         names   gpa
# 0  24030099    ziad salah  3.59
# 1  24030100   ziad radwan  3.30
# 2  24030101  ziad mohamed  3.48

# %%
df.describe()
# Out:
#        Customer_Age   Unit_Price     Quantity  Discount_Percent       Rating  \
# count    5000.00000  5000.000000  5000.000000       5000.000000  5000.000000
# mean       41.32860   655.597086     1.985400          0.071330     3.752440
# std        13.76791   413.307520     1.064995          0.074858     0.724557
# min        18.00000   110.400000     1.000000          0.000000     2.500000
# 25%        29.00000   317.082500     1.000000          0.000000     3.100000
# 50%        41.00000   647.680000     2.000000          0.050000     3.800000
# 75%        53.00000   844.812500     3.000000          0.150000     4.400000
# max        65.00000  1877.060000     4.000000          0.200000     5.000000
#
#        Stock_Available_Before_Sale  Lead_Time_Days  Competitor_Price
# count                  5000.000000     5000.000000       5000.000000
# mean                    128.608400        7.788600        671.709736
# std                      70.878379        3.843913        427.256737
# ...

# %%
df['Product_Name']
# Out:
# 0       Basic Cotton T-Shirt
# 1               Skincare Set
# 2                 Sunglasses
# 3                  Body Mist
# 4             Aroma Diffuser
#                 ...
# 4995                     Cap
# 4996            Basic Blouse
# 4997                  Hoodie
# 4998              Sunglasses
# 4999            Leather Belt
# Name: Product_Name, Length: 5000, dtype: object

# %%
print(df['Product_Name'].value_counts())
# Out:
# Product_Name
# Polo Shirt              193
# Basic Blouse            186
# Scented Candle          182
# Wide Leg Pants          179
# Aroma Diffuser          178
# Backpack                178
# White Sneakers          176
# Skincare Set            175
# Casual Dress            174
# Summer Dress            173
# Minimal Wallet          173
# Linen Set               173
# Hair Serum              172
# Slides                  169
# Men Perfume 50ml        168
# Slim Fit Jeans          168
# Notebook                165
# Water Bottle            164
# Leather Belt            162
# Hoodie                  161
# Leather Loafers         161
# Basic Cotton T-Shirt    159
# Running Shoes           158
# Cap                     157
# Women Perfume 50ml      155
# Women Sandals           153
# Sunglasses              152
# Ceramic Mug             148
# Oversized T-Shirt       146
# Body Mist               142
# Name: count, dtype: int64

# %%
print(df['Customer_Area'].unique())
print(df['Customer_Area'].nunique())
# Out:
# ['Smouha' 'Victoria' 'Stanley' 'Mandara' 'Sporting' 'Roushdy' 'Louran'
#  'Sidi Bishr' 'Gleem' 'Miami']
# 10

# %%
print(df['Branch'].unique())
# Out:
# ['Smouha' 'Stanley' 'Miami' 'Downtown Alexandria' 'Sidi Bishr' 'Mandara'
#  'Gleem' 'Roushdy']

# %%
print(df['Customer_Gender'].unique())
# Out:
# ['Male' 'Female']

# %%
df.isnull().sum()
# Out:
# Order_ID                          0
# Order_Date                        0
# Order_Time                        0
# Branch                            0
# Sales_Channel                     0
# Customer_ID                       0
# Customer_Gender                   0
# Customer_Age                      0
# Customer_Area                     0
# Product_ID                        0
# Product_Name                      0
# Category                          0
# Brand                             0
# Unit_Price                        0
# Quantity                          0
# Discount_Percent                  0
# Payment_Method                    0
# Marketing_Source                  0
# Campaign_Name                     0
# Returned                          0
# Return_Reason                  4682
# Rating                            0
# Stock_Available_Before_Sale       0
# Supplier                          0
# Lead_Time_Days                    0
# Competitor_Price                  0
# ...

# %%
print(df['Quantity'].isnull().mean())
# Out:
# 0.0

# %%
print(df.isnull().sum())

missing_values = df['Return_Reason'].isnull().sum()
print(f"missing values in Return_Reason: {missing_values}")


print('----------------------------------')

print(df['Order_Time'].sort_values())
# Out:
# Order_ID                          0
# Order_Date                        0
# Order_Time                        0
# Branch                            0
# Sales_Channel                     0
# Customer_ID                       0
# Customer_Gender                   0
# Customer_Age                      0
# Customer_Area                     0
# Product_ID                        0
# Product_Name                      0
# Category                          0
# Brand                             0
# Unit_Price                        0
# Quantity                          0
# Discount_Percent                  0
# Payment_Method                    0
# Marketing_Source                  0
# Campaign_Name                     0
# Returned                          0
# Return_Reason                  4682
# Rating                            0
# Stock_Available_Before_Sale       0
# Supplier                          0
# Lead_Time_Days                    0
# Competitor_Price                  0
# ...

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Order_ID                     5000 non-null   object
#  1   Order_Date                   5000 non-null   object
#  2   Order_Time                   5000 non-null   object
#  3   Branch                       5000 non-null   object
#  4   Sales_Channel                5000 non-null   object
#  5   Customer_ID                  5000 non-null   object
#  6   Customer_Gender              5000 non-null   object
#  7   Customer_Age                 5000 non-null   int64
#  8   Customer_Area                5000 non-null   object
#  9   Product_ID                   5000 non-null   object
#  10  Product_Name                 5000 non-null   object
#  11  Category                     5000 non-null   object
#  12  Brand                        5000 non-null   object
# ...

# %%
## filteeer
df[(df["Unit_Price"] > 500) & (df["Discount_Percent"] == 0.20)]
# Out:
#        Order_ID  Order_Date Order_Time      Branch Sales_Channel Customer_ID  \
# 1     ORD000002  2025-01-07      14:10     Stanley      WhatsApp       C0105
# 25    ORD000026  2025-12-27      16:15     Mandara       Website       C0280
# 28    ORD000029  2025-04-28      19:00     Roushdy   TikTok Shop       C0694
# 30    ORD000031  2025-10-02      14:50     Stanley     Instagram       C0584
# 42    ORD000043  2025-12-15      14:20     Mandara       Website       C0458
# ...         ...         ...        ...         ...           ...         ...
# 4909  ORD004910  2025-10-18      15:50  Sidi Bishr       Website       C0868
# 4924  ORD004925  2025-11-26      22:20       Miami   TikTok Shop       C0080
# 4963  ORD004964  2025-03-20      10:45  Sidi Bishr       Website       C0715
# 4976  ORD004977  2025-01-14      16:05     Stanley   TikTok Shop       C0836
# 4997  ORD004998  2025-09-21      13:15     Stanley     Instagram       C0334
#
# ...

# %%
dc = pd.read_csv('D:/TECHTRECK/retail_sales_raw.csv')

print(dc.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2628 entries, 0 to 2627
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order ID         2628 non-null   object
#  1   Order Date       2628 non-null   object
#  2   Customer ID      2628 non-null   object
#  3   Product ID       2628 non-null   object
#  4   Category         2628 non-null   object
#  5   Product          2628 non-null   object
#  6   Region           2628 non-null   object
#  7   City             2589 non-null   object
#  8   Channel          2628 non-null   object
#  9   Payment Method   2563 non-null   object
#  10  Sales Rep        2628 non-null   object
#  11  Quantity         2628 non-null   int64
#  12  Unit Price       2612 non-null   float64
#  13  Unit Cost        2628 non-null   float64
#  14  Discount %       2628 non-null   float64
#  15  Shipping Cost    2628 non-null   float64
# ...

# %%
dc.describe()
# Out:
#           Quantity    Unit Price     Unit Cost   Discount %  Shipping Cost  \
# count  2628.000000   2612.000000   2628.000000  2628.000000    2628.000000
# mean      1.811263   5553.607343   3736.032922     4.726027     108.324041
# std       1.590367   8036.763066   6184.797414     6.869071      53.930365
# min       1.000000    585.730000    235.890000     0.000000      35.010000
# 25%       1.000000   1320.670000    614.462500     0.000000      74.977500
# 50%       1.000000   2404.015000   1246.920000     0.000000     106.735000
# 75%       2.000000   4286.987500   2641.202500    10.000000     137.885000
# max      29.000000  35795.690000  28928.560000    25.000000    1087.440000
#
#        Customer Rating
# count      2419.000000
# mean          4.111823
# std           0.592440
# min           2.100000
# 25%           3.700000
# 50%           4.100000
# 75%           4.500000
# max           5.000000

# %%
list(dc.columns)
# Out:
# ['Order ID',
#  'Order Date',
#  'Customer ID',
#  'Product ID',
#  'Category',
#  'Product',
#  'Region',
#  'City',
#  'Channel',
#  'Payment Method',
#  'Sales Rep',
#  'Quantity',
#  'Unit Price',
#  'Unit Cost',
#  'Discount %',
#  'Shipping Cost',
#  'Customer Rating',
#  'Returned']

# %%
print(dc.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2628 entries, 0 to 2627
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order ID         2628 non-null   object
#  1   Order Date       2628 non-null   object
#  2   Customer ID      2628 non-null   object
#  3   Product ID       2628 non-null   object
#  4   Category         2628 non-null   object
#  5   Product          2628 non-null   object
#  6   Region           2628 non-null   object
#  7   City             2589 non-null   object
#  8   Channel          2628 non-null   object
#  9   Payment Method   2563 non-null   object
#  10  Sales Rep        2628 non-null   object
#  11  Quantity         2628 non-null   int64
#  12  Unit Price       2612 non-null   float64
#  13  Unit Cost        2628 non-null   float64
#  14  Discount %       2628 non-null   float64
#  15  Shipping Cost    2628 non-null   float64
# ...

# %%
print(dc.shape)
row , col = dc.shape
print(row , col)
# Out:
# (2628, 18)
# 2628 18

# %%
dc.columns
## to convert to normal list
list(dc.columns)
# Out:
# ['Order ID',
#  'Order Date',
#  'Customer ID',
#  'Product ID',
#  'Category',
#  'Product',
#  'Region',
#  'City',
#  'Channel',
#  'Payment Method',
#  'Sales Rep',
#  'Quantity',
#  'Unit Price',
#  'Unit Cost',
#  'Discount %',
#  'Shipping Cost',
#  'Customer Rating',
#  'Returned']

# %%
print(dc.dtypes)
print("----------------------------------------")
print(dc.dtypes.value_counts())
# Out:
# Order ID            object
# Order Date          object
# Customer ID         object
# Product ID          object
# Category            object
# Product             object
# Region              object
# City                object
# Channel             object
# Payment Method      object
# Sales Rep           object
# Quantity             int64
# Unit Price         float64
# Unit Cost          float64
# Discount %         float64
# Shipping Cost      float64
# Customer Rating    float64
# Returned            object
# dtype: object
# ----------------------------------------
# object     12
# float64     5
# int64       1
# Name: count, dtype: int64

# %%
print(dc.index) ##where start and end
print(dc.index.min())  ## the first
print(dc.index.max())  ## the last
# Out:
# RangeIndex(start=0, stop=2628, step=1)
# 0
# 2627

# %%
print("First 5 rows:")
print(dc.head())

print("Random 5 rows:")
print(dc.sample(5, random_state=42))  # Displaying random rows
# Out:
# First 5 rows:
#      Order ID  Order Date Customer ID Product ID        Category  \
# 0  ORD-100232  2025-09-08       C0370       P016          Beauty
# 1  ORD-102198  2025-08-22       C0090       P016          Beauty
# 2  ORD-100331  2025-01-20       C0305       P013          Beauty
# 3  ORD-100920  2025-04-26       C0256       P008  Home & Kitchen
# 4  ORD-102003  2025-08-18       C0674       P015          Beauty
#
#         Product      Region        City      Channel    Payment Method  \
# 0    Makeup Kit       Delta    Mansoura  Marketplace  Cash on Delivery
# 1    Makeup Kit       Delta       Tanta        Store       Credit Card
# 2       Perfume       Cairo   New Cairo   Mobile App       Credit Card
# 3  Cookware Set  Alexandria  Sidi Gaber      Website       Credit Card
# 4    Hair Dryer  Alexandria  Sidi Gaber   Mobile App       Credit Card
#
#   Sales Rep  Quantity  Unit Price  Unit Cost  Discount %  Shipping Cost  \
# ...

# %%
print(dc[['Order ID', 'Order Date']])
# Out:
#         Order ID  Order Date
# 0     ORD-100232  2025-09-08
# 1     ORD-102198  2025-08-22
# 2     ORD-100331  2025-01-20
# 3     ORD-100920  2025-04-26
# 4     ORD-102003  2025-08-18
# ...          ...         ...
# 2623  ORD-101697  2025-07-15
# 2624  ORD-100332  2025-12-28
# 2625  ORD-101293  2025-10-20
# 2626  ORD-101104  2025-10-13
# 2627  ORD-101945  2025-06-04
#
# [2628 rows x 2 columns]

# %%
print(dc['City'].value_counts())
# Out:
# City
# Damietta      187
# Tanta         179
# Nasr City     179
# Minya         177
# Agami         169
# Miami         168
# Mansoura      168
# Zagazig       163
# New Cairo     160
# Assiut        158
# Luxor         158
# Heliopolis    154
# Maadi         153
# Sidi Gaber    149
# Smouha        138
# Sohag         129
# Name: count, dtype: int64

# %%
print(dc['Region'].unique())
print(dc['Region'].nunique())
# Out:
# ['Delta' 'Cairo' 'Alexandria' 'Upper Egypt']
# 4

# %%
print(dc.isnull().sum())
# Out:
# Order ID             0
# Order Date           0
# Customer ID          0
# Product ID           0
# Category             0
# Product              0
# Region               0
# City                39
# Channel              0
# Payment Method      65
# Sales Rep            0
# Quantity             0
# Unit Price          16
# Unit Cost            0
# Discount %           0
# Shipping Cost        0
# Customer Rating    209
# Returned             0
# dtype: int64

# %%
dc.tail()
# Out:
#         Order ID  Order Date Customer ID Product ID        Category  \
# 2623  ORD-101697  2025-07-15       C0208       P012         Fashion
# 2624  ORD-100332  2025-12-28       C0503       P003     Electronics
# 2625  ORD-101293  2025-10-20       C0692       P008  Home & Kitchen
# 2626  ORD-101104  2025-10-13       C0234       P003     Electronics
# 2627  ORD-101945  2025-06-04       C0428       P011         Fashion
#
#            Product      Region       City      Channel    Payment Method  \
# 2623       T-Shirt       Cairo  Nasr City  Marketplace            Wallet
# 2624    Headphones  Alexandria     Smouha      Website  Cash on Delivery
# 2625  Cookware Set       Delta   Damietta   Mobile App            Wallet
# 2626    Headphones  Alexandria      Agami        Store       Credit Card
# 2627      Backpack  Alexandria      Miami   Mobile App  Cash on Delivery
#
#      Sales Rep  Quantity  Unit Price  Unit Cost  Discount %  Shipping Cost  \
# ...

# %%
missing_values = dc['Shipping Cost'].isnull().sum()
print(f"missing values in Shipping Cost: {missing_values}")
# Out:
# missing values in Shipping Cost: 0

# %%
print(dc['Shipping Cost'].sort_values())
# Out:
# 137       35.01
# 310       35.02
# 1212      35.16
# 2467      35.18
# 808       35.19
#          ...
# 2007     768.32
# 2039     783.68
# 1629     783.68
# 1552     833.84
# 1818    1087.44
# Name: Shipping Cost, Length: 2628, dtype: float64

# %%
print(dc['Payment Method'].duplicated().sum())
print(dc['Payment Method'].duplicated())
# Out:
# 2623
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 2623     True
# 2624     True
# 2625     True
# 2626     True
# 2627     True
# Name: Payment Method, Length: 2628, dtype: bool

# %%
df.describe(include='all')
# Out:
#          Order_ID  Order_Date Order_Time  Branch Sales_Channel Customer_ID  \
# count        5000        5000       5000    5000          5000        5000
# unique       5000         542        104       8             5         897
# top     ORD005000  2025-06-24      21:45  Smouha   TikTok Shop       C0776
# freq            1          20         63     671          1028          14
# mean          NaN         NaN        NaN     NaN           NaN         NaN
# std           NaN         NaN        NaN     NaN           NaN         NaN
# min           NaN         NaN        NaN     NaN           NaN         NaN
# 25%           NaN         NaN        NaN     NaN           NaN         NaN
# 50%           NaN         NaN        NaN     NaN           NaN         NaN
# 75%           NaN         NaN        NaN     NaN           NaN         NaN
# max           NaN         NaN        NaN     NaN           NaN         NaN
#
# ...

# %%
dc.select_dtypes(include='number').columns
# Out:
# Index(['Quantity', 'Unit Price', 'Unit Cost', 'Discount %', 'Shipping Cost',
#        'Customer Rating'],
#       dtype='object')

# %%
print(dc['Product'].value_counts())
# Out:
# Product
# Treadmill        155
# Air Fryer        149
# Perfume          148
# Headphones       147
# Sneakers         143
# Makeup Kit       139
# Dumbbell Set     134
# Smart Watch      134
# Coffee Maker     131
# Hair Dryer       131
# Laptop           128
# Skin Care Set    127
# T-Shirt          126
# Backpack         125
# Smartphone       123
# Blender          122
# Jacket           121
# Football         120
# Yoga Mat         118
# Cookware Set     107
# Name: count, dtype: int64

# %%
print(dc['Category'].unique())
# Out:
# ['Beauty' 'Home & Kitchen' 'Sports' 'fashion' 'Electronics' 'Fashion'
#  ' Beauty ' 'sports' 'beauty' 'home & kitchen' ' home & kitchen '
#  ' Sports ' 'electronics' ' Electronics ' ' Fashion ' ' Home & Kitchen ']

# %%
dc.iloc[0]
# Out:
# Order ID                 ORD-100232
# Order Date               2025-09-08
# Customer ID                   C0370
# Product ID                     P016
# Category                     Beauty
# Product                  Makeup Kit
# Region                        Delta
# City                       Mansoura
# Channel                 Marketplace
# Payment Method     Cash on Delivery
# Sales Rep                      Nour
# Quantity                          1
# Unit Price                  1216.26
# Unit Cost                    491.81
# Discount %                     10.0
# Shipping Cost                 44.39
# Customer Rating                 3.4
# Returned                        Yes
# Name: 0, dtype: object

# %%
df.iloc[:3]
# Out:
#     Order_ID  Order_Date Order_Time   Branch Sales_Channel Customer_ID  \
# 0  ORD000001  2025-04-25      21:05   Smouha   TikTok Shop       C0433
# 1  ORD000002  2025-01-07      14:10  Stanley      WhatsApp       C0105
# 2  ORD000003  2025-03-22      15:15   Smouha         Store       C0678
#
#   Customer_Gender  Customer_Age Customer_Area Product_ID  \
# 0            Male            19        Smouha       P001
# 1            Male            42        Smouha       P025
# 2            Male            36        Smouha       P018
#
#            Product_Name            Category      Brand  Unit_Price  Quantity  \
# 0  Basic Cotton T-Shirt        Men Clothing  UrbanWear      212.22         1
# 1          Skincare Set  Beauty & Fragrance   BlueLine      783.53         4
# 2            Sunglasses         Accessories  UrbanWear      500.98         4
#
#    Discount_Percent Payment_Method Marketing_Source Campaign_Name Returned  \
# ...

# %%
df.loc[df['Quantity'] > 2]  ## useful for filtering then update the values in the filtered rows
# Out:
#        Order_ID  Order_Date Order_Time               Branch Sales_Channel  \
# 1     ORD000002  2025-01-07      14:10              Stanley      WhatsApp
# 2     ORD000003  2025-03-22      15:15               Smouha         Store
# 3     ORD000004  2025-10-01      12:15                Miami     Instagram
# 7     ORD000008  2025-04-25      14:15           Sidi Bishr       Website
# 11    ORD000012  2026-03-30      20:00               Smouha       Website
# ...         ...         ...        ...                  ...           ...
# 4980  ORD004981  2026-03-20      11:20  Downtown Alexandria   TikTok Shop
# 4989  ORD004990  2025-03-11      10:00               Smouha       Website
# 4994  ORD004995  2026-02-01      17:30               Smouha   TikTok Shop
# 4997  ORD004998  2025-09-21      13:15              Stanley     Instagram
# 4999  ORD005000  2026-03-06      22:15                Miami      WhatsApp
#
#      Customer_ID Customer_Gender  Customer_Age Customer_Area Product_ID  \
# ...
